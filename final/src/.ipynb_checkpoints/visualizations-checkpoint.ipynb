# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sb
import pandas as pd
import numpy as np
import scipy as sp

import time

from numpy import random as rd
from scipy import stats

# %%
data = pd.read_csv('../data2/train.csv')

# %%
N = 100
X = data.ix[0:N]

def plot_list(l):
    x = X[l]
    sb.pairplot(x, hue='opened')
    
plot_list(['contest_login_count_30_days', 'contest_participation_count_30_days', 'mail_category', 'opened'])
plot_list(['mail_type', 'mail_category', 'opened'])

# %%
sb.swarmplot(x="mail_type", y="mail_category", hue="opened", data=X)
plt.show()
sb.swarmplot(x="forum_count", y="mail_category", hue="opened", data=X)
plt.show()
sb.swarmplot(x="sent_time", y="open_time", hue="opened", data=X)
plt.show()
